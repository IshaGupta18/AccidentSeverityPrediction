# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ml-project
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1EYMdZLRTdcPuJ5_rIIaX4w-t7oZvIr0-/ml-project
# 'Accident Severity Prediction.gslides'	      nn-model-epoch-200.pt
#  dvc					      nn-model-epoch-250.pt
# 'Exploratory Data Analysis - Group 14.gdoc'   nn-model-epoch-300.pt
#  ml-project				      nn-model-epoch-350.pt
# 'ML Project .gdoc'			      nn-model-epoch-50.pt
#  ml-project.zip				      testing_data.csv
# 'ML Report.gdoc'			      traning_data.csv
#  nn-model-epoch-0.pt			      y_test.npy
#  nn-model-epoch-100.pt			      y_train.npy
#  nn-model-epoch-150.pt

# %%
# %cd /content/drive/MyDrive/ml/ml-project
# !ls
# Out:
# /content/drive/MyDrive/ml/ml-project
# 'Accident Severity Prediction.gslides'	      nn-model-epoch-200.pt
#  dvc					      nn-model-epoch-250.pickle
# 'Exploratory Data Analysis - Group 14.gdoc'   nn-model-epoch-250.pt
#  ml-project				      nn-model-epoch-300.pickle
# 'ML Project .gdoc'			      nn-model-epoch-300.pt
#  ml-project.zip				      nn-model-epoch-350.pt
# 'ML Report.gdoc'			      nn-model-epoch-50.pickle
#  nn-model-epoch-0.pickle		      nn-model-epoch-50.pt
#  nn-model-epoch-0.pt			      testing_data.csv
#  nn-model-epoch-100.pickle		      tmp.pickle
#  nn-model-epoch-100.pt			      traning_data.csv
#  nn-model-epoch-150.pickle		      y_test.npy
#  nn-model-epoch-150.pt			      y_train.npy
#  nn-model-epoch-200.pickle

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
from torch.utils.data import Dataset
from torch.utils.data import DataLoader, random_split

import torchvision.transforms as transforms
import torchvision.datasets as datasets

import matplotlib.pyplot as plt
import numpy as np

import copy
import random
import time

import pandas as pd
import os
# imports pytorch
import torch
import pickle


# imports the torch_xla package
# import torch_xla
# import torch_xla.core.xla_model as xm

# %%
class us_dataset(Dataset):
	"""
	Dataloader class for loading the training and testing data of q3
	"""
	def __init__(self,train = True):
		if train:        
			self.X = pd.read_csv("traning_data.csv").values
			self.y = np.load("y_train.npy") - 1
		else:
			self.X = pd.read_csv("testing_data.csv").values
			self.y = np.load("y_test.npy") - 1
		
	def __len__(self):
		return self.X.shape[0]

	def __getitem__(self, idx):
		return self.X[idx],self.y[idx]

class MLP(nn.Module):
	def __init__(self, input_dim, output_dim):
		super().__init__()
			
		# self.input_fc = nn.Linear(input_dim, 512)
		self.input_fc = nn.Linear(input_dim, 32)
		#torch.nn.init.normal_(self.input_fc.weight)

		# self.hidden_1 = nn.Linear(512, 256)
		self.hidden_1 = nn.Linear(32, 32)
		#torch.nn.init.normal_(self.hidden_1.weight)

		self.hidden_2 = nn.Linear(32, 16)

		self.hidden_3 = nn.Linear(16, 16)

		# self.output_fc = nn.Linear(256, output_dim)
		self.losses = []
		self.output_fc = nn.Linear(16, output_dim)
		#torch.nn.init.normal_(self.output_fc.weight)

		
	def forward(self, x):
		batch_size = x.shape[0]
		x = x.view(batch_size, -1)
		h_1 = F.relu(self.input_fc(x))
		h_2 = F.relu(self.hidden_1(h_1))
		h_3 = F.relu(self.hidden_2(h_2))
		h_4 = F.relu(self.hidden_3(h_3))
		y_pred = self.output_fc(h_3)

		return y_pred, h_1

def calculate_accuracy(y_pred, y):
	"""
		Function for calculating the accuracy of the predictied values 
	"""
	top_pred = y_pred.argmax(1, keepdim = True)
	correct = top_pred.eq(y.view_as(top_pred)).sum()
	acc = correct.float() / y.shape[0]
	return acc

def train(model, iterator, optimizer, criterion, device):
	
	epoch_loss = 0
	epoch_acc = 0
	
	model.train()
	
	for (x, y) in iterator:
		
		x = x.to(device)
		y = y.to(device)
		
		optimizer.zero_grad()
				
		y_pred, _ = model(x.float())
		
		loss = criterion(y_pred, y.long())
		
		acc = calculate_accuracy(y_pred, y)
		
		loss.backward()
		
		optimizer.step()
		
		epoch_loss += loss.item()
		epoch_acc += acc.item()
		
	return epoch_loss / len(iterator), epoch_acc / len(iterator)

def evaluate(model, iterator, criterion, device):
	
	epoch_loss = 0
	epoch_acc = 0
	
	model.eval()
	
	with torch.no_grad():
		
		for (x, y) in iterator:

			x = x.to(device)
			y = y.to(device)

			y_pred, _ = model(x.float())

			loss = criterion(y_pred, y.long())

			acc = calculate_accuracy(y_pred, y)

			epoch_loss += loss.item()
			epoch_acc += acc.item()
		
	return epoch_loss / len(iterator), epoch_acc / len(iterator)

def epoch_time(start_time, end_time):
	"""
	Helper function for calculating the time required for one epoch
 
	"""
	elapsed_time = end_time - start_time
	elapsed_mins = int(elapsed_time / 60)
	elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
	return elapsed_mins, elapsed_secs

# %%
train_dataset1 = us_dataset()
test_dataset1 = us_dataset(False)

trainset1, valset1 = random_split(train_dataset1, [2159442, 239938])

BATCH_SIZE = 512

#divide the data into batches
train_iterator1 = DataLoader(trainset1, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
valid_iterator1 = DataLoader(valset1, batch_size=BATCH_SIZE, num_workers=4)
test_iterator1 = DataLoader(test_dataset1, batch_size=BATCH_SIZE, num_workers=4)

INPUT_DIM = 37
OUTPUT_DIM = 4

# define he model 
model = MLP(INPUT_DIM, OUTPUT_DIM)

optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss()
device = torch.device('cuda') # if torch.cuda.is_available() else 'cpu')
model = model.to(device)
criterion = criterion.to(device)


EPOCHS = 1000

best_valid_loss = float('inf')

# %%
#training loop

# train_loss = [0]*EPOCHS
# train_acc = [0]*EPOCHS
# valid_loss = [0]*EPOCHS
# valid_acc = [0]*EPOCHS

for epoch in range(EPOCHS):

    start_time = time.monotonic()

    #one epoch
    train_loss, train_acc = train(model, train_iterator1, optimizer, criterion, device)
    valid_loss, valid_acc = evaluate(model, valid_iterator1, criterion, device)
    model.losses.append({'epoch' : epoch,
                         'train_loss' : train_loss,
                         'train_acc' : train_acc,
                         'valid_loss' : valid_loss,
                         'valid_acc' : valid_acc})
    if epoch % 50 == 0 or epoch == EPOCHS - 1:
        #torch.save(model.state_dict(), f'nn-model-epoch-{epoch}.pt')
        pickle.dump(model,open(f'nn-model-epoch-{epoch}.pickle',"wb"))

    end_time = time.monotonic()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')

# %%
model.load_state_dict(torch.load('nn-model-epoch-150.pt'))
# Out:
# <All keys matched successfully>

# %%
model.losses
# Out:
# []

# %%
pickle.dump(model,open("tmp.pickle","wb"))

# %%
model = pickle.load(open("nn-model-epoch-300.pickle","rb"))

# %%
train_dataset1 = us_dataset()
test_dataset1 = us_dataset(False)

trainset1, valset1 = random_split(train_dataset1, [2159442, 239938])

BATCH_SIZE = 512

#divide the data into batches
train_iterator1 = DataLoader(trainset1, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
valid_iterator1 = DataLoader(valset1, batch_size=BATCH_SIZE, num_workers=4)
test_iterator1 = DataLoader(test_dataset1, batch_size=BATCH_SIZE, num_workers=4)

# %%
def my_test(model,iterator,device):
    model.eval()
    output = []    
    tru = []
    with torch.no_grad():
      
      for (x, y) in iterator:

        x = x.to(device)
        y = y.to(device)

        y_pred, _ = model(x.float())
        output.extend(y_pred)
        tru.extend(y)
    return output, tru

# %%
output, tru = my_test(model,test_iterator1,device = torch.device('cuda'))

# %%
len(output), len(tru)
# Out:
# (1028307, 1028307)

# %%
output[0].argmax(), tru[0].cpu().numpy()
# Out:
# (tensor(1, device='cuda:0'), array(2))

# %%
from tqdm import tqdm
out = []
j = []
for i in tqdm(output):
  out.append(i.argmax().cpu().numpy())

for i in tqdm(tru):
  j.append(i.cpu().numpy())
# Out:
# 100%|██████████| 1028307/1028307 [00:39<00:00, 26094.32it/s]
# 100%|██████████| 1028307/1028307 [00:19<00:00, 53424.00it/s]

# %%
from sklearn.metrics import classification_report

print(classification_report(j, out))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.22      0.32      8581
#            1       0.74      0.89      0.81    695600
#            2       0.57      0.34      0.42    291575
#            3       0.53      0.24      0.33     32551
#
#     accuracy                           0.71   1028307
#    macro avg       0.61      0.42      0.47   1028307
# weighted avg       0.69      0.71      0.68   1028307

# %%
epoch_ans = [i for i in range(1,301)]
train_loss_ans = [i['train_loss'] for i in model.losses]
test_loss_ans = [i['valid_loss'] for i in model.losses]

plt.plot(epoch_ans, train_loss_ans[:-2], label = "Average Training Loss")
plt.plot(epoch_ans, test_loss_ans[:-2], label = "Average Validation Loss")
plt.xlabel('Epochs')
plt.ylabel("Corss-entropy Loss")
plt.legend(loc='best')
plt.savefig(f"neural_net_loss_plot.png")
plt.show()

# %%
criterion = nn.CrossEntropyLoss()
device = torch.device('cuda') # if torch.cuda.is_available() else 'cpu')

evaluate(model, test_iterator1, criterion, device)
# Out:
# (0.5976780806387639, 0.710149438242345)

# %%
pip install kmeanstf

# %%
from kmeanstf import KMeansTF
import pandas as pd
import numpy as np

# %%
X = pd.read_csv("traning_data.csv").values
y = np.load("y_train.npy")

# %%
km = KMeansTF(n_clusters=10, random_state=1234, verbose = 1, max_iter = 1000, tol = 1e-16)
km.fit(X[y == 2])
# Out:
# _k_means(): k-means init #0, init=k-means++  tolerance reached at Lloyd iter 27 SSE=3400934.25000: 0.00000E+00 < 8.35003E-18 (tol)
#  k-means SSE: 3400934.25000
#
# _k_means(): k-means init #1, init=k-means++  tolerance reached at Lloyd iter 40 SSE=3395004.25000: 0.00000E+00 < 8.35003E-18 (tol)
#  k-means SSE: 3395004.25000
#
# _k_means(): k-means init #2, init=k-means++  tolerance reached at Lloyd iter 26 SSE=3322534.25000: 0.00000E+00 < 8.35003E-18 (tol)
#  k-means SSE: 3322534.25000
#
# _k_means(): k-means init #3, init=k-means++  tolerance reached at Lloyd iter 30 SSE=3394549.75000: 0.00000E+00 < 8.35003E-18 (tol)
#  k-means SSE: 3394549.75000
#
# _k_means(): k-means init #4, init=k-means++  tolerance reached at Lloyd iter 29 SSE=3319467.25000: 0.00000E+00 < 8.35003E-18 (tol)
#  k-means SSE: 3319467.25000
#
# _k_means(): k-means init #5, init=k-means++  tolerance reached at Lloyd iter 118 SSE=3372975.00000: 0.00000E+00 < 8.35003E-18 (tol)
#  k-means SSE: 3372975.00000
#
# _k_means(): k-means init #6, init=k-means++  tolerance reached at Lloyd iter 39 SSE=3402600.00000: 0.00000E+00 < 8.35003E-18 (tol)
#  k-means SSE: 3402600.00000
#
# _k_means(): k-means init #7, init=k-means++  tolerance reached at Lloyd iter 12 SSE=3295742.50000: 0.00000E+00 < 8.35003E-18 (tol)
#  k-means SSE: 3295742.50000
#
# _k_means(): k-means init #8, init=k-means++  tolerance reached at Lloyd iter 76 SSE=3439631.75000: 0.00000E+00 < 8.35003E-18 (tol)
#  k-means SSE: 3439631.75000
#
# _k_means(): k-means init #9, init=k-means++  tolerance reached at Lloyd iter 35 SSE=3367710.00000: 0.00000E+00 < 8.35003E-18 (tol)
#  k-means SSE: 3367710.00000

# %%
from sklearn.cluster import KMeans

# %%
Sum_of_squared_distances = []
for k in range(2,16):
    print(f"k = {k}")
    km = KMeans(n_clusters=k,verbose=1, max_iter = 1000)
    km = km.fit(X[y == 2])
    Sum_of_squared_distances.append(km.inertia_)
# Out:
# k = 2
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4725228.472743185
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4658869.718917232
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4588488.025630801
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4534352.596792191
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4519484.449294041
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4519484.449294041
# center shift 0.000000e+00 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4753747.497093017
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4692734.184277119
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4658696.773426725
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4635976.897925456
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4620169.203260733
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4585806.77087665
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4567376.1801307425
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4563293.548805503
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4558009.919078203
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4541780.913833711
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4539250.084115233
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4539236.152837578
# center shift 2.485876e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4724446.56595813
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4614285.006430121
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4579857.9892264465
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4535546.217246489
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4519484.449294041
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4519484.449294041
# center shift 0.000000e+00 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4635635.984465832
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4571142.828715501
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4524346.998168153
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4519484.449294041
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4519484.449294041
# center shift 0.000000e+00 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4804543.2683969615
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4721854.548191034
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4604491.093901004
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4547182.642271595
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4533722.089421298
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4533722.089421298
# center shift 0.000000e+00 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4598565.763416031
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4550461.897755026
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4539847.9837059
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4539246.317194358
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4539236.215734783
# center shift 2.461402e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4752735.342931075
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4729311.961497324
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4721203.746849016
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4716880.01595661
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4715194.049546165
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4715193.986789239
# center shift 2.072718e-11 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4641143.565952253
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4567461.737149283
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4563798.319023213
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4560808.935867955
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4548119.010599524
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4539318.261153385
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4539236.656744645
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4539235.953615445
# center shift 1.909343e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4680678.519938049
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4622481.688300478
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4609302.94910906
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4606006.640522191
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4603178.22381046
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4600902.079551655
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4598553.011280791
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4598386.214649974
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4598385.717826913
# center shift 1.542314e-08 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4640812.229284727
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4535949.406241077
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4519484.449294041
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4519484.449294041
# center shift 0.000000e+00 within tolerance 8.350048e-06
# k = 3
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4548120.817224406
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4423485.375662758
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4384771.709849072
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4382800.02543169
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4372999.952685295
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4330087.168751993
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4264837.5034599295
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4240255.4887603205
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4240255.4887603205
# center shift 0.000000e+00 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4531163.515586426
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4402654.212113757
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4369431.762026873
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4358702.537016106
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4338717.735026093
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4299813.512516469
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4269564.843866399
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4233755.828770579
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4215128.275233712
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4214747.4056280395
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4214689.074929302
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4214686.466531036
# center shift 5.237749e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4620425.613046668
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4471598.179788736
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4347273.024837868
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4313964.73218445
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4298862.179946586
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4298857.590396619
# center shift 8.501745e-09 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4401768.104783429
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4317713.127656622
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4313816.5824527
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4308683.442921665
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4293130.119126414
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4289514.73102729
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4289512.465028673
# center shift 4.513282e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4483933.456398417
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4368463.893128202
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4360021.461795685
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4358930.223636067
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4358744.714489008
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4358209.680742918
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4355746.880754924
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4342729.20167138
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4342200.700138172
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4342161.134105614
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4342100.772314951
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4341972.8121885015
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4341659.990011222
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4340666.01150971
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 4337678.209980983
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 4337302.7799630575
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 4337302.554682314
# center shift 2.436832e-09 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4529734.574119138
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4460979.534403971
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4432220.586310491
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4407279.065419621
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4382546.942837514
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4365857.423539274
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4358600.686857015
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4337800.352874368
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4320222.594738705
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4319871.933631857
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4319514.127009795
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4318916.740194688
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4317471.003939136
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4316201.205660508
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 4315478.082796818
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 4315288.581824915
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 4315114.102351235
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 4314937.280376898
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 4314892.313022367
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 4314889.805976931
# center shift 5.352921e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4550899.494615842
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4481149.311071914
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4454616.569924771
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4433567.336247568
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4399988.770422517
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4343207.944303367
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4326188.449292648
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4312276.9545527175
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4278763.896538012
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4277783.318223948
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4277783.318223948
# center shift 0.000000e+00 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4528990.636148538
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4459119.179243232
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4390782.533025139
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4350646.933216425
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4324382.27941377
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4315452.8683619
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4315452.8683619
# center shift 0.000000e+00 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4684845.46692688
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4541698.121625243
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4465080.428539314
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4430930.077765033
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4426545.902394067
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4421451.682377438
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4407376.370852756
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4395008.46710739
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4371670.357801661
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4303162.112425829
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4273007.451686287
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4249695.2030425295
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4221574.175829798
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4214913.680168576
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 4214720.844077709
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 4214687.12815212
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 4214686.456205261
# center shift 1.184107e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4680064.319450708
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4560254.651394311
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4493363.456314562
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4440177.848901599
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4380808.678975489
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4366621.256744899
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4343061.755914187
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4310753.249664683
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4299548.590637031
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4297469.25611268
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4296828.530825112
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4295011.140971218
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4288643.874438001
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4285675.826389621
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 4283710.561523409
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 4267568.483156301
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 4261923.7863255385
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 4261923.7863255385
# center shift 0.000000e+00 within tolerance 8.350048e-06
# k = 4
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4313754.5382238915
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4195638.794953289
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4143151.587164154
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4099258.70296716
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4087369.188935598
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4086558.355022144
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4086230.609274068
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4085503.7684318307
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4085106.2947749314
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4084915.3479148573
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4083949.8275693785
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4078066.139184905
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4077875.1109134355
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4077874.3107318142
# center shift 7.251380e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4447746.200430843
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4243100.7629460385
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4154102.614558173
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4100058.974129804
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4075600.0481524537
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4053977.4775193096
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4045319.1912266845
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4042562.98545944
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4040823.4188991087
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4040823.4188991087
# center shift 0.000000e+00 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4349943.566441202
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4178219.2782371454
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4103257.5266415444
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4049472.6532277702
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4026056.492784924
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4006206.205056091
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3992501.2973389113
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3992222.2448092517
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3992220.9141626665
# center shift 4.564851e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4425858.783699988
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4315697.879859112
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4242377.294006263
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4176780.103061266
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4125230.3776503205
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4098585.2872426617
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4090183.70215212
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4077919.648176292
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4046120.63630335
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4023107.1184680504
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4011673.756767313
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4005930.5373294223
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4005418.2336104834
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4005405.9876062446
# center shift 3.878644e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4426232.662289042
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4319034.87041694
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4262834.6512364
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4187778.3245620034
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4133943.8541996325
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4130403.5114149824
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4121440.8653146867
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4111626.225556699
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4108039.047038035
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4106588.1808779794
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4099817.359661601
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4096527.8729696167
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4093296.470444721
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4067648.8231434617
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 4067639.617995933
# center shift 1.020762e-08 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4295393.8404145045
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4107760.605221019
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4062357.384375401
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4045224.11086199
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4043371.9635764724
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4040478.390886896
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4034264.731971702
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4033812.4372489536
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4033788.5569927325
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4033778.7979935347
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4033729.690324796
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4033000.1551374504
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4024310.529359935
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 4015906.343150728
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 4015827.2018889342
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 4015815.58952085
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 4015813.485887198
# center shift 1.486612e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4439537.398519137
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4331750.478425468
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4230785.84666345
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4127906.0796119883
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4111120.215592548
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4100461.4050410115
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4098505.0058192685
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4097648.5371501255
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4097604.0997969215
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4097603.878696696
# center shift 2.866141e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4341397.807850347
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4156737.8508619615
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4097845.629947808
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4083786.437568928
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4077458.457984577
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4066006.546355753
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4037544.563901773
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4017455.8041545283
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4013079.395929207
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4010348.172450097
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4008063.4525048393
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4001035.2542550047
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3987584.214068482
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3965493.5631487365
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3964919.2546160365
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3964911.952861376
# center shift 3.313927e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4424639.770641453
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4128150.037376574
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4040781.0624685152
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3988676.3674766775
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3965027.691980945
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3964914.827953672
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3964911.623094155
# center shift 1.557761e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4533554.718025169
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4349244.311346509
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4299373.96137171
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4216048.688402099
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4163395.344908341
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 4123110.6515924395
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 4103840.2974939262
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 4080433.7496120012
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 4077310.7624264834
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 4072843.8640233707
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 4062220.16344178
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 4045663.098888552
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 4015364.995025882
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3989862.293965939
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3980475.3171497486
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3978199.8491888754
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3978166.8940480645
# center shift 4.046240e-06 within tolerance 8.350048e-06
# k = 5
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4211058.273593631
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4069743.9756043674
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4016431.5554521643
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3998114.037412757
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3962457.6591015453
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3934594.046143476
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3929657.8432162986
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3929434.7186380285
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3929428.9495275016
# center shift 3.479412e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4234122.978506292
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4052664.2514463533
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3996195.0636701467
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3959395.6521917265
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3934052.6686958256
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3908417.508797212
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3894476.1833645524
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3890149.570997011
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3881575.815934132
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3872913.223012484
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3872844.9874669607
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3872823.775143797
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3872814.1383442264
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3872810.9889574484
# center shift 4.089145e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4298162.511620463
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4101221.0208011796
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4018045.81429221
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3986075.577995364
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3984251.5758704785
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3982494.033274884
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3978158.251925252
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3974431.972461361
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3973495.1150375786
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3973408.921392075
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3973386.7241342394
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3973364.391817738
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3973298.5436369665
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3973141.3870106144
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3972739.067610045
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3972098.8584914105
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3972015.232293454
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3972013.4286730234
# center shift 8.764254e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4287471.7591140615
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4129239.665352411
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4066736.9141464387
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4017163.8643120895
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3980671.304590656
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3963096.2843137
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3946300.161051116
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3923879.3170931796
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3903012.573911725
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3902493.357559513
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3902362.6627621325
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3902276.277919417
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3902195.2105506123
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3902108.5429280004
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3902037.2807540093
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3901943.3993918435
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3901703.980855
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3900797.2159125083
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3898332.1528303083
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3894027.4988889582
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 3891482.8993271897
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 3891471.512902062
# center shift 5.174598e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4270965.634954574
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4096358.919056782
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4030745.22335592
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3996740.6303037046
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3953759.9269342218
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3937948.020038979
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3934031.8724650913
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3931276.810920666
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3925278.7219713046
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3901081.3065265687
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3895088.2469821223
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3894642.5534505616
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3893587.080705876
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3887651.9413854913
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3884908.010474842
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3883488.2560876254
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3880635.5980860326
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3879927.721856725
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3879898.969211877
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3879875.836813951
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 3879852.519202793
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 3879832.709710435
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 3879816.677359411
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 3879806.237923511
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 3879800.82414156
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 3879797.2557645417
# center shift 6.878428e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4317494.924174188
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4203068.987123389
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4096526.9834392513
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4033246.5338304876
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 4009063.0784825874
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3994873.7192067243
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3988212.5708764438
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3981019.5640613236
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3973151.02677781
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3965551.0697468906
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3953804.463482535
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3946829.075768621
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3940647.7375797047
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3938716.6914076176
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3938306.075368304
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3937885.0003201114
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3937200.9051514394
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3934016.3004004923
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3926007.6191503475
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3924044.744097083
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 3923876.680200658
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 3923864.879644534
# center shift 7.147768e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4231128.909486424
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4114715.1884808443
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 4047215.501626438
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 4021528.372810264
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3994469.0251757903
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3983406.335774033
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3969733.8103085975
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3954006.370139805
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3935600.2506584753
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3914585.494477034
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3870379.2030519396
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3837852.8333929004
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3803326.0422136257
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3800532.1736200177
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3800523.27504875
# center shift 3.288994e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4295880.587351224
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4060037.531025977
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3988802.0705732303
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3945918.342173554
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3920364.0941840913
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3911564.059147098
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3907583.7737234286
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3906559.8524653157
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3905584.483319251
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3904045.650625289
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3898260.0362033653
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3888539.0988614843
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3888392.8372498187
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3888391.029520388
# center shift 9.297776e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4237053.31175012
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 4036278.845248877
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3934791.3046481023
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3895571.737650599
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3838100.18991656
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3815089.7774354154
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3801505.903228262
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3801377.366061521
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3801363.754563512
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3801362.3729496705
# center shift 9.579947e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4152375.5415003593
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3945040.318274414
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3890557.118560808
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3876026.4351307442
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3859929.1586228767
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3846103.6562025296
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3824870.846276255
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3823843.071169152
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3823771.782519674
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3823762.159070361
# center shift 7.920371e-06 within tolerance 8.350048e-06
# k = 6
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4143984.01824461
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3959151.3419193286
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3835778.6768097216
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3778836.0318565397
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3775382.6883557793
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3774784.1396700367
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3774315.2404461186
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3772933.7369077783
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3772211.9473249754
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3771615.3287607166
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3770650.075625822
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3767337.195700114
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3764359.115381732
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3764179.1877864054
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3763907.126574292
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3763111.0618722057
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3760758.796892502
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3757689.059152078
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3756204.850549888
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3755715.2285578907
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 3755125.251989385
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 3753744.5512642623
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 3750156.3871172247
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 3745052.5046453713
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 3743727.1658789096
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 3743338.1883428586
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 3743285.9803415295
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 3743241.862317235
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 3743170.5852295533
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 3743093.3172990973
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 3743034.969537265
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 3743007.650382411
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 3742999.6760235485
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 3742994.1768619157
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 3742987.925659199
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 3742975.501645963
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 3742941.65872321
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 3742883.2545315223
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 3742832.852457715
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 3742814.0732546085
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 3742811.763400812
# center shift 3.115079e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4200342.359029677
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3999496.209198963
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3911971.361349526
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3872755.9914645213
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3853799.8818810973
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3833952.088853103
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3818115.8295544423
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3802827.74445895
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3797506.2336448072
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3796181.6919698585
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3793346.02936958
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3785433.870572437
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3784930.361978697
# start iteration
# done sorting
# end inner loop
# ...
# end inner loop
# Iteration 12, inertia 3633844.601664709
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3633719.4658015873
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3633700.2682231525
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3633691.7302653436
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3633678.292309772
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3633658.2674565683
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3633649.7949591405
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3633647.2513570907
# center shift 4.603137e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4005626.299029557
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3801585.910937268
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3736885.972263553
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3716302.818234818
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3699617.941286212
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3682970.5967327715
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3679607.6384844426
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3677277.769384886
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3674593.5021455614
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3667265.0678739687
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3661250.6494088727
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3660841.4272175436
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3660799.9603849994
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3660790.9261000645
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3660782.073415769
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3660769.743460785
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3660750.4078041534
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3660727.1227517165
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3660713.4909034264
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3660710.413769355
# center shift 5.107571e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4050137.4016919904
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3893036.084629136
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3842579.0629395777
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3813683.4094677456
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3782030.3604129395
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3738078.1228208314
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3702766.593049157
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3671347.1072054408
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3658745.0624583336
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3648478.8176192357
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3643580.951566386
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3641862.1181518873
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3641347.224550577
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3641113.1274972213
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3640254.282609057
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3639811.809976775
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3639680.4286139086
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3639543.0075810216
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3639134.148160513
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3638892.033257489
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 3638611.931047218
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 3638320.5438926877
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 3637434.7829018426
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 3636013.9993708017
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 3635552.4660149263
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 3635364.350455693
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 3635247.8861972727
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 3634760.7950485507
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 3634084.486389968
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 3633921.4529807726
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 3633806.9479514365
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 3633668.1840911675
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 3633527.4017386665
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 3633331.8643201822
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 3633198.2858722364
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 3633024.742907017
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 3632798.9847084708
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 3632602.3942695027
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 3632348.561188046
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 3631188.6685052947
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 3630155.210910962
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 3629386.0457830275
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 3628901.61299526
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 3627403.060820289
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 3626014.27270604
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 3625662.759971615
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 3625608.321438644
# start iteration
# done sorting
# end inner loop
# Iteration 47, inertia 3625601.0330833
# start iteration
# done sorting
# end inner loop
# Iteration 48, inertia 3625600.384300087
# center shift 7.554055e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 3991727.7505752686
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3821088.19985992
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3768196.7966575264
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3736276.2257816144
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3703454.405608348
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3678354.6072059516
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3666614.549027003
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3654695.943160607
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3637768.345750686
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3627491.3845737386
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3620759.3881411892
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3617209.6727321353
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3616248.0866262326
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3615519.519217362
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3615298.0821128753
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3614951.9257228277
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3613928.1055466784
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3610493.446812448
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3609642.867467479
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3609549.1504172697
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 3609504.9815874416
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 3609496.6473697745
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 3609493.8225956135
# center shift 5.157254e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4058613.842279244
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3897044.796605727
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3818728.6659425367
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3779658.002501083
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3740392.55747056
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3674951.2810373018
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3640138.854678802
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3633311.480121032
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3631715.800173723
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3630429.1348458226
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3628821.0357753243
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3626750.218453069
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3625827.9481129074
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3624954.4885136257
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3624818.836461616
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3624637.198054827
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3624457.9546688385
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3624424.941087913
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3624424.6224365113
# center shift 1.118954e-07 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4017724.348094437
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3838815.3219555058
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3773160.6672727475
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3710368.6140317456
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3681153.9143252177
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3662156.515367768
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3645297.5010226844
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3637144.9190166993
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3632785.8407613244
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3630787.9698806764
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3629249.8193512238
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3610863.757558613
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3601671.846807959
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3601539.0608321405
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3601436.1803773353
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3601386.077501285
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3601368.9425456612
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3601342.0463846107
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3601334.487170512
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3601332.317822363
# center shift 3.891559e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4114333.1453628712
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3885666.1763278297
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3767053.7562245326
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3719268.327826145
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3692489.2293942505
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3670159.185206723
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3660349.1624138225
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3657181.107949335
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3654586.4126247535
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3650557.0720229307
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3644636.253941827
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3640270.3829429448
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3639994.930064393
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3639662.721689698
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3639371.440171324
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3639025.7077509314
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3637916.2160708252
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3637063.8983430625
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3636123.3953889045
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3635625.098507694
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 3635494.2772506773
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 3635457.9434592384
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 3635447.089757914
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 3635443.643622758
# center shift 6.415178e-06 within tolerance 8.350048e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 4092003.5222708685
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 3859488.7080396735
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 3780467.729325181
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 3729420.0297381226
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 3695323.5186902704
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 3678535.5153397317
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 3666522.283896758
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 3656533.837701763
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 3645051.6773776324
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 3641624.991067209
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 3637970.474818267
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 3629910.967748905
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 3623418.6201043297
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 3621970.810400243
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 3621522.1128151403
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 3621391.5458843224
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 3620368.4114962313
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 3619848.5909844767
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 3619220.0983062508
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 3619215.7086039437
# center shift 2.622189e-06 within tolerance 8.350048e-06
# k = 8

# %%
km.inertia_
# Out:
# 3295742.5
